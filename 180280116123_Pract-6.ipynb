# %% [markdown]
# # 180280116123 Sharad Vala

# %% [markdown]
# ## Data Visulization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# ### 1) BarChart

# %%
df=pd.read_csv('Downloads/2020.csv')
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %% [markdown]
# plot using artist layer of matplotlib

# %% [markdown]
# stacked = true

# %%
ax1=df.plot(kind='bar',stacked=True,figsize=(20,8),alpha=0.70,color=['skyblue','brown','orange','red'])
ax1.set_title('World Happiness Report')
ax1.set_xlabel('Subject')
ax1.set_ylabel('Ratio')
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# stacked = false

# %%
ax1=df.plot(kind='bar',stacked=False,figsize=(20,8),alpha=0.70,color=['skyblue','brown','orange','red'])
ax1.set_title('World Happiness Report')
ax1.set_xlabel('Subject')
ax1.set_ylabel('Ratio')
# Out:
# Text(0, 0.5, 'Ratio')

# %% [markdown]
# ### 2) Histogram

# %%
df.plot(kind='hist', figsize=(10, 6),bins=15,alpha=0.6,stacked=True,)
plt.title('World Happiness Report')
plt.ylabel('Subjects')
plt.xlabel('Ladder Score')
plt.show()

# %% [markdown]
# ### 3) Box plot

# %%
df.plot(kind='box', figsize=(8, 6))

plt.title('Box Plot Ladder Score')
plt.ylabel('Number of country')

plt.show()

# %% [markdown]
# ### 4) PieChart

# %%
df=pd.read_csv('Downloads/continents2.csv')
df.head()
# Out:
#             name alpha-2 alpha-3  country-code     iso_3166-2  region  \
# 0    Afghanistan      AF     AFG             4  ISO 3166-2:AF    Asia
# 1  Åland Islands      AX     ALA           100  ISO 3166-2:AX  Europe
# 2        Albania      AL     ALB             8  ISO 3166-2:AL  Europe
# 3        Algeria      DZ     DZA            12  ISO 3166-2:DZ  Africa
# 4          Turky      TK     TRK            18            NaN    Asia
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN          142               34
# 1  Northern Europe                 NaN          150              154
# 2  Southern Europe                 NaN          110               39
# 3  Northern Africa                 NaN            2               15
# 4          Northen                Asia           36               23
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
print('data dimensions:', df.shape)
# Out:
# data dimensions: (8, 11)

# %%
df_continents = df.groupby('name', axis=0).sum()

# note: the output of the groupby method is a `groupby' object. 
# we can not use it further until we apply a function (eg .sum())
print(type(df.groupby('name', axis=0)))

df_continents.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#              country-code  region-code  sub-region-code  \
# name
# Afghanistan             4          142               34
# Albania                 8          110               39
# Algeria                12            2               15
# Aus                     9           70               55
# Mangol                 25            6               20
#
#              intermediate-region-code
# name
# Afghanistan                       0.0
# Albania                           0.0
# Algeria                           0.0
# Aus                               0.0
# Mangol                            0.0

# %%
explode_list = [0, 0, 0, 0, 0]
df_continents['country-code'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%',
                            startangle=90,  
                            shadow=True,
                             pctdistance=1.15,
                            labels=None,
                           # add shadow      
                            )

plt.title('Continents')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# ### 5) Scatter Plot

# %%
df.plot(kind='scatter', x='country-code', y='region-code', figsize=(10, 6), color='skyblue')
plt.title('Continents')
plt.xlabel('Country-code')
plt.ylabel('Region-code')

plt.show()

# %% [markdown]
# ### 6) LineChart

# %%
plt.plot(df['country-code'], df['region-code'], color='green', marker='o')
plt.title('Continents')
plt.xlabel('Country-code')
plt.ylabel('Region-code')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 7) Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
text_file = open('Downloads/Sp.txt', 'r').read()
    
print ('File downloaded and saved!')
# Out:
# File downloaded and saved!

# %%
stopwords = set(STOPWORDS)

# %%
wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
wc.generate(text_file)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df=pd.read_csv('Downloads/courses.csv')
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
sns.set()
sns.relplot(x="num_subscribers",y="level",data=df)

# %% [markdown]
# ### 8) Catplot

# %%
dt=df['content_duration'].str.split('')
df['hour']=dt.str.get(1)
df['hour']=df['hour'].astype(int)

# %%
sns.catplot(x="hour",y="subject",kind='bar',data=df);

# %%
plt.subplot(142)
plt.title('Count of Paid Vs. Free Courses',fontsize = 15)
sns.countplot(df['is_paid'])

# %%
#this displays the distribution of the number of subscribers
plt.figure(figsize=(10,8))
plt.style.use('ggplot')
sns.distplot(np.log(df['num_subscribers']+1))
plt.xlabel('Number of Subscribers')
plt.title('Normal distribution of the number of subscribers')
# Out:
# Text(0.5, 1.0, 'Normal distribution of the number of subscribers')

# %%
#this displays the Corr. between Number of Subscribers & price
plt.figure(figsize=(10,8))
plt.title('Corr. between Number of Subscribers and Price',fontsize = 20)
sns.regplot(y=df['num_subscribers'],x=df['price'])
plt.style.use('ggplot')
plt.xticks(rotation = 90)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# ### 9) Heatmap

# %%
features=df[['num_subscribers','num_reviews','num_lectures','price','content_duration']]

# %%
## correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(features.corr(), linewidths=.5, annot=True, cmap='Reds', cbar=True)
plt.title('Correlation of Numerical Variables', fontsize=14, weight='bold')
plt.style.use('ggplot')
plt.show()
